# %%
# !pip install pandas

# %%
import pandas as pd

# %%
a = (1,2,3,4,5,6)

b = ["one","two","three","four","five","six"] 

#dtype=int

x = pd.Series(data = b)
x
# Out:
# 0      one
# 1      two
# 2    three
# 3     four
# 4     five
# 5      six
# dtype: object

# %%
y = pd.Series(data = a, index=b, dtype= str)
y
# Out:
# one      1
# two      2
# three    3
# four     4
# five     5
# six      6
# dtype: object

# %%
#Series from list
a = [1,2,3,4]
b = ("I","II","III","IV")
s = pd.Series(data = a, index= b ,dtype=int)
s
# Out:
# I      1
# II     2
# III    3
# IV     4
# dtype: int32

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# Index(['I', 'II', 'III', 'IV'], dtype='object')

# %%
s.values
# Out:
# array([1, 2, 3, 4])

# %%
data = pd.Series([1,2,3,4.6])
data
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.6
# dtype: float64

# %%
data[2]
# Out:
# 3.0

# %%
data[:4]
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.6
# dtype: float64

# %%
data[-3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: -3 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data[-3]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# ...

# %%
data[::-1]
# Out:
# 3    4.6
# 2    3.0
# 1    2.0
# 0    1.0
# dtype: float64

# %%
age = {'ram' : 28,'bob' : 19, 'cam' : 22}

s = pd.Series(data= age, index=['bob','ram','cam',"hello"],dtype=int)
s
# Out:
# bob      19.0
# ram      28.0
# cam      22.0
# hello     NaN
# dtype: float64

# %%
population_dict ={'California':38332521,
                 'Texas':26448193,
                 'New York':19651127,
                 'Florida':19562860,
                 'Florida':19662860,
                 'Illinois':12882135,
                 'Illinois':12892135}
population_series = pd.Series(population_dict)
population_series
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19662860
# Illinois      12892135
# dtype: int64

# %%
area_dict = {'California':423967,
            'Texas':695662,
            'New York':141297,
            'Florida':170312,
            'Illinois':149995}
area_series = pd.Series(area_dict) 
area_series
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states = pd.DataFrame({'population':population_series,
                      'area':area_series})
states
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19662860  170312
# Illinois      12892135  149995

# %%
type(states)
# Out:
# pandas.core.frame.DataFrame

# %%
type(states.area)
# Out:
# pandas.core.series.Series

# %%
data = [["A",34,23,56],["B",92,88,76],["C",76," ",25],["D"," ",78,99]]

stu = pd.DataFrame(data, columns=["Name",'Maths','Phy','Chem'],index=[1,2,3,4])
stu
# Out:
#   Name Maths Phy  Chem
# 1    A    34  23    56
# 2    B    92  88    76
# 3    C    76        25
# 4    D        78    99

# %%
stu["Phy", "Chem"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Phy', 'Chem')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 stu["Phy", "Chem"]
#
# ...

# %%
stu[["Phy", "Chem", "Maths"]]
# Out:
#   Phy  Chem Maths
# 1  23    56    34
# 2  88    76    92
# 3        25    76
# 4  78    99

# %%
stu.replace(" ",0)
# Out:
#   Name  Maths  Phy  Chem
# 1    A     34   23    56
# 2    B     92   88    76
# 3    C     76    0    25
# 4    D      0   78    99

# %%
# Selecting Columns
d = {'Chem' : pd.Series([30, 70, 35,25,26,67,77,67,89], index=["Raj",'Ram', 'Asa', 'Pi','Chi','Ru',"Sita","Ria","Gita"],dtype=int),
     'Math' : pd.Series([18, 26, 35, 40,55,89,79,100], index=["Raj",'Ram', 'Pi', 'Chi', 'Ru',"Sita","Ria","Gita"],dtype=int),
     'Phy' : pd.Series([31, 42, 83,34,80,78], index=["Asa",'Ram', 'Pi', 'Ru',"Sita","Gita"],dtype=int)}



exam = pd.DataFrame(d)
exam1=exam.copy() ## To make copy of your data
exam1
# Out:
#       Chem   Math   Phy
# Asa     35    NaN  31.0
# Chi     26   40.0   NaN
# Gita    89  100.0  78.0
# Pi      25   35.0  83.0
# Raj     30   18.0   NaN
# Ram     70   26.0  42.0
# Ria     67   79.0   NaN
# Ru      67   55.0  34.0
# Sita    77   89.0  80.0

# %%
print ("Adding a new column using the existing columns in DataFrame:")

exam1['Total'] = exam1['Chem']+exam1['Math']+exam1['Phy']
exam1
# Out:
# Adding a new column using the existing columns in DataFrame:
#       Chem   Math   Phy  Total
# Asa     35    NaN  31.0    NaN
# Chi     26   40.0   NaN    NaN
# Gita    89  100.0  78.0  267.0
# Pi      25   35.0  83.0  143.0
# Raj     30   18.0   NaN    NaN
# Ram     70   26.0  42.0  138.0
# Ria     67   79.0   NaN    NaN
# Ru      67   55.0  34.0  156.0
# Sita    77   89.0  80.0  246.0

# %%
exam1.isnull().sum()
# Out:
# Chem     0
# Math     1
# Phy      3
# Total    4
# dtype: int64

# %%
exam1 = exam1.fillna(0)

# %%
exam1
# Out:
#       Chem   Math   Phy  Total
# Asa     35    0.0  31.0    0.0
# Chi     26   40.0   0.0    0.0
# Gita    89  100.0  78.0  267.0
# Pi      25   35.0  83.0  143.0
# Raj     30   18.0   0.0    0.0
# Ram     70   26.0  42.0  138.0
# Ria     67   79.0   0.0    0.0
# Ru      67   55.0  34.0  156.0
# Sita    77   89.0  80.0  246.0

# %%
a = exam1["Math"].median()
a
#exam1["Math"] = exam1["Math"].fillna(a)
# Out:
# 40.0

# %%
exam1["Avg"] = (exam1["Math"] + exam1["Phy"] + exam1["Chem"])/3
exam1
# Out:
#       Chem   Math   Phy  Total        Avg
# Asa     35    0.0  31.0    0.0  22.000000
# Chi     26   40.0   0.0    0.0  22.000000
# Gita    89  100.0  78.0  267.0  89.000000
# Pi      25   35.0  83.0  143.0  47.666667
# Raj     30   18.0   0.0    0.0  16.000000
# Ram     70   26.0  42.0  138.0  46.000000
# Ria     67   79.0   0.0    0.0  48.666667
# Ru      67   55.0  34.0  156.0  52.000000
# Sita    77   89.0  80.0  246.0  82.000000

# %%
exam1["Math"].replace(0.0, a)
# Out:
# Asa      40.0
# Chi      40.0
# Gita    100.0
# Pi       35.0
# Raj      18.0
# Ram      26.0
# Ria      79.0
# Ru       55.0
# Sita     89.0
# Name: Math, dtype: float64

# %%
exam1.drop(["Total"] )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 exam1.drop(["Total"] )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# ...

# %%
exam1.drop(["Total"], axis = 1 )
# Out:
#       Chem   Math   Phy        Avg
# Asa     35    0.0  31.0  22.000000
# Chi     26   40.0   0.0  22.000000
# Gita    89  100.0  78.0  89.000000
# Pi      25   35.0  83.0  47.666667
# Raj     30   18.0   0.0  16.000000
# Ram     70   26.0  42.0  46.000000
# Ria     67   79.0   0.0  48.666667
# Ru      67   55.0  34.0  52.000000
# Sita    77   89.0  80.0  82.000000

# %%
exam1
# Out:
#       Chem   Math   Phy  Total        Avg
# Asa     35    0.0  31.0    0.0  22.000000
# Chi     26   40.0   0.0    0.0  22.000000
# Gita    89  100.0  78.0  267.0  89.000000
# Pi      25   35.0  83.0  143.0  47.666667
# Raj     30   18.0   0.0    0.0  16.000000
# Ram     70   26.0  42.0  138.0  46.000000
# Ria     67   79.0   0.0    0.0  48.666667
# Ru      67   55.0  34.0  156.0  52.000000
# Sita    77   89.0  80.0  246.0  82.000000

# %%
exam1.drop(["Total"], axis = 1, inplace = True )

# %%
exam1
# Out:
#       Chem   Math   Phy        Avg
# Asa     35    0.0  31.0  22.000000
# Chi     26   40.0   0.0  22.000000
# Gita    89  100.0  78.0  89.000000
# Pi      25   35.0  83.0  47.666667
# Raj     30   18.0   0.0  16.000000
# Ram     70   26.0  42.0  46.000000
# Ria     67   79.0   0.0  48.666667
# Ru      67   55.0  34.0  52.000000
# Sita    77   89.0  80.0  82.000000

# %%
df = pd.read_csv("C:\\Users\\amitm\\Downloads\\sales_data_final.csv")

# %%
df.head(20)
# Out:
#            order_id order_date ship_date       ship_mode      customer_name  \
# 0      AG-2011-2040   1/1/2011  1/6/2011  Standard Class    Toby Braunhardt
# 1     IN-2011-47883   1/1/2011  1/8/2011  Standard Class        Joseph Holt
# 2      HU-2011-1220   1/1/2011  1/5/2011    Second Class      Annie Thurman
# 3   IT-2011-3647632   1/1/2011  1/5/2011    Second Class       Eugene Moren
# 4     IN-2011-47883   1/1/2011  1/8/2011  Standard Class        Joseph Holt
# 5     IN-2011-47883   1/1/2011  1/8/2011  Standard Class        Joseph Holt
# 6      CA-2011-1510   1/2/2011  1/6/2011  Standard Class    Magdelene Morse
# 7     IN-2011-79397   1/3/2011  1/3/2011        Same Day        Kean Nguyen
# 8     ID-2011-80230   1/3/2011  1/9/2011  Standard Class       Ken Lonsdale
# 9      IZ-2011-4680   1/3/2011  1/7/2011  Standard Class   Lindsay Williams
# 10    IN-2011-65159   1/3/2011  1/7/2011    Second Class       Larry Blacks
# ...

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.sample(5)
# Out:
#               order_id order_date  ship_date       ship_mode customer_name  \
# 431      IN-2011-81833  1/31/2011   2/6/2011  Standard Class  Troy Staebel
# 3489    CA-2011-100090   7/8/2011  7/12/2011  Standard Class    Ed Braxton
# 33893    IN-2014-71102   1/6/2014  1/10/2014  Standard Class      Rob Dowd
# 4472   ES-2011-5340910  8/21/2011  8/21/2011        Same Day  Pamela Stobb
# 26250   US-2013-105452  7/29/2013   8/2/2013  Standard Class   Barry Franz
#
#            segment       state        country market        region  ...  \
# 431       Consumer  Wellington    New Zealand   APAC       Oceania  ...
# 3489     Corporate  California  United States     US          West  ...
# 33893     Consumer      Punjab          India   APAC  Central Asia  ...
# 4472      Consumer      Madrid          Spain     EU         South  ...
# 26250  Home Office       Texas  United States     US       Central  ...
#
#               category sub_category                              product_name  \
# ...

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.shape
# Out:
# (51290, 21)

# %%
var = df.columns

# %%
df.count()
# Out:
# order_id          51290
# order_date        51290
# ship_date         51290
# ship_mode         51290
# customer_name     51290
# segment           51290
# state             51290
# country           51290
# market            51290
# region            51290
# product_id        51290
# category          51290
# sub_category      51290
# product_name      51290
# sales             51290
# quantity          51290
# discount          51290
# profit            51290
# shipping_cost     51290
# order_priority    51290
# year              51290
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.sum()
# Out:
# order_id          AG-2011-2040IN-2011-47883HU-2011-1220IT-2011-3...
# order_date        1/1/20111/1/20111/1/20111/1/20111/1/20111/1/20...
# ship_date         1/6/20111/8/20111/5/20111/5/20111/8/20111/8/20...
# ship_mode         Standard ClassStandard ClassSecond ClassSecond...
# customer_name     Toby BraunhardtJoseph HoltAnnie ThurmanEugene ...
# segment           ConsumerConsumerConsumerHome OfficeConsumerCon...
# state             ConstantineNew South WalesBudapestStockholmNew...
# country           AlgeriaAustraliaHungarySwedenAustraliaAustrali...
# market            AfricaAPACEMEAEUAPACAPACCanadaAPACAPACEMEAAPAC...
# region            AfricaOceaniaEMEANorthOceaniaOceaniaCanadaOcea...
# product_id        OFF-TEN-10000025OFF-SU-10000618OFF-TEN-1000158...
# category          Office SuppliesOffice SuppliesOffice SuppliesO...
# sub_category      StorageSuppliesStoragePaperFurnishingsPaperMac...
# product_name      Tenex Lockers, BlueAcme Trimmer, High SpeedTen...
# ...

# %%
df.profit.sum()
# Out:
# 1469034.8212799998

# %%
df.index
# Out:
# RangeIndex(start=0, stop=51290, step=1)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.drop([51288,51289])
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51283    IN-2014-23754  12/31/2014  1/7/2015  Standard Class
# 51284   MX-2014-108574  12/31/2014  1/4/2015  Standard Class
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.drop([51288, 51289], inplace=True)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51283    IN-2014-23754  12/31/2014  1/7/2015  Standard Class
# 51284   MX-2014-108574  12/31/2014  1/4/2015  Standard Class
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df["segment"].unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
df["segment"].replace('Home Office', "Home")
# Out:
# 0         Consumer
# 1         Consumer
# 2         Consumer
# 3             Home
# 4         Consumer
#            ...
# 51283    Corporate
# 51284         Home
# 51285    Corporate
# 51286     Consumer
# 51287     Consumer
# Name: segment, Length: 51288, dtype: object

# %%
df["segment"].unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
df["segment"].replace('Home Office', "Home", inplace=True)

# %%
df["segment"].unique()
# Out:
# array(['Consumer', 'Home', 'Corporate'], dtype=object)

# %%
df["segment"] = df["segment"].replace("Home",'Home Office')

# %%
df["segment"].unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df["market"].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df["market"].unique().count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
df["market"].value_counts()
# Out:
# market
# APAC      11002
# LATAM     10293
# EU        10000
# US         9993
# EMEA       5029
# Africa     4587
# Canada      384
# Name: count, dtype: int64

# %%
df[["market","profit"]].groupby("market")
